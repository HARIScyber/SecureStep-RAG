# %% [markdown]
# # Attack Demonstration
# Inject cascade payloads and observe blocked documents.

# %%
from attack.cascade_attack import inject_cascade_attack
from pipeline.graph import SecureStepGraph
inject_cascade_attack()
g = SecureStepGraph()
out = g.run('Summarize SOC2 access controls')
len(out['blocked_docs']), out['hop_queries']
