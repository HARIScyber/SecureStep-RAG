# %% [markdown]
# # SecureStep-RAG Exploration
# Inspect retrieved documents and trust scores per hop.

# %%
from pipeline.graph import SecureStepGraph
graph = SecureStepGraph()
result = graph.run('How does zero-trust reduce lateral movement?')
result
