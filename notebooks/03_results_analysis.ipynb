# %% [markdown]
# # Results Analysis
# Run ablation and compare defended vs undefended metrics.

# %%
from eval.ablation import run_ablation
results = run_ablation()
[(r.name, r.faithfulness, r.attack_success_rate, r.blocked_doc_count) for r in results]
